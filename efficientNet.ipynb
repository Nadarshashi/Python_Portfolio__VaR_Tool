# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadarshashi/Python_Portfolio__VaR_Tool/blob/master/efficientNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
names = ['ResNet-18', 'ResNet-34', 'ResNet-50', 'ResNet-101', 'ResNet-152', 'Wide ResNet-50-2', 'Wide ResNet-101-2']
accuracies = [100-30.24, 100-26.70, 100-23.85, 100-22.63, 100-21.69, 100-21.49, 100-21.16]
plt.figure(figsize=(12, 5))
plt.plot(names[:-2], accuracies[:-2])
plt.scatter(names[:-2], accuracies[:-2])
plt.plot(names[-2:], accuracies[-2:], color='red')
plt.scatter(names[-2:], accuracies[-2:], color='red')
plt.xlabel('Model')
plt.ylabel('Imagenet Top-1 Accuracy')
# Out:
# Text(0, 0.5, 'Imagenet Top-1 Accuracy')

# %%
accuracies
# Out:
# [69.76, 73.3, 76.15, 77.37, 78.31, 78.51, 78.84]
